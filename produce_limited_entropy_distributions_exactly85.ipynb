# %% [markdown]
# ### Introduction
#
# This notebook sets out to produce distributions that are randomly sampled from the space of
# distributions which entropy is set to a fixed percentage of the maximum entropy

# %%
import os
import numpy as np
from scipy import stats
import pickle
import probability_distributions
import limited_entropy_distributions as limited_entropy

# %%
PATH = "/home/joboti/azumi_derkjan/master_thesis/code/"
PERCENTAGE_MAX_ENTROPY = 75
TOP_FOLDER = "system_distributions/limited_entropy/"
FOLDER_PERCENTAGE_MAX_ENTROPY = "entropy{}/".format(PERCENTAGE_MAX_ENTROPY)
FOLDER_DISTRIBUTION_SHAPE_FORMAT = "{}var_{}states/"
FILENAME_DISTRIBUTION_FORMAT = "dist_{}_exact.npy"
MIN_NUMBER_VARIABLES = 2
MAX_NUMBER_VARIABLES = 7
NUMBER_OF_STATES = 3

FILENAME_INPUT_FORMAT = "input_dist_exact_{}.npy"
FILENAME_COND_OUTPUT_FORMAT = "cond_output_dist_exact_{}.npy" 

NUMBER_OF_SAMPLES = 100
START_NUMBER_SAMPLES = 200
END_NUMBER_SAMPLES = 300

MAX_CHANGE = 10**(-3)

# %% [markdown]
# #### generate the folder structure (if needed)

# %%
if not os.path.exists(PATH+TOP_FOLDER):
    os.makedirs(PATH+TOP_FOLDER)
    
if not os.path.exists(PATH+TOP_FOLDER+FOLDER_PERCENTAGE_MAX_ENTROPY):
    os.makedirs(PATH+TOP_FOLDER+FOLDER_PERCENTAGE_MAX_ENTROPY)

for number_of_variables in range(MIN_NUMBER_VARIABLES, MAX_NUMBER_VARIABLES+1, 1):
    directory = (PATH+TOP_FOLDER+FOLDER_PERCENTAGE_MAX_ENTROPY
                 + FOLDER_DISTRIBUTION_SHAPE_FORMAT.format(number_of_variables, NUMBER_OF_STATES))
                 
    if not os.path.exists(directory):
        os.makedirs(directory)

# %%
import limited_entropy_distributions

print(np.log2(3**2) * 0.8)
dist = limited_entropy_distributions.get_dist_percentage_max_entropy_exactly([3]*2, 0.8, 10**(-3))
print(np.sum(dist))
print(stats.entropy(dist.flatten(), base=2))
# Out:
# 2.53594000115
# 1.0
# 2.53515199519

# %%
RUN = True
if RUN:
    for number_of_variables in range(MIN_NUMBER_VARIABLES, MAX_NUMBER_VARIABLES+1, 1):
        print("number of variables {}".format(number_of_variables))
        directory = (
            PATH + TOP_FOLDER + FOLDER_PERCENTAGE_MAX_ENTROPY
            + FOLDER_DISTRIBUTION_SHAPE_FORMAT.format(number_of_variables, NUMBER_OF_STATES)
        )
        dist_shape = [NUMBER_OF_STATES]*number_of_variables
        goal_entropy = np.log2(NUMBER_OF_STATES**number_of_variables) * PERCENTAGE_MAX_ENTROPY/100.0
        print("goal entropy {}".format(goal_entropy))
        for sample_number in range(START_NUMBER_SAMPLES, END_NUMBER_SAMPLES, 1):
            good_entropy = False
            while not good_entropy:
                dist = limited_entropy_distributions.get_dist_percentage_max_entropy_exactly(
                    dist_shape, PERCENTAGE_MAX_ENTROPY/100.0, MAX_CHANGE
                )
                if abs(stats.entropy(dist.flatten(), base=2)/goal_entropy - 1) < 0.05:
                    good_entropy = True
                    
            print("sample number {} entropy {}".format(sample_number, stats.entropy(dist.flatten(), base=2)))

            #save distribution
            file_name = FILENAME_DISTRIBUTION_FORMAT.format(sample_number)
            with open(directory+file_name, 'wb') as f:
                np.save(f, dist)
# Out:
# number of variables 2
# goal entropy 2.53594000115
# sample number 200 entropy 2.53576708211
# sample number 201 entropy 2.53578856179
# sample number 202 entropy 2.53496604259
# sample number 203 entropy 2.53499024448
# sample number 204 entropy 2.53443659891
# sample number 205 entropy 2.53587001996
# sample number 206 entropy 2.53521510378
# sample number 207 entropy 2.53566411375
# sample number 208 entropy 2.53588461035
# sample number 209 entropy 2.53563066486
# sample number 210 entropy 2.4420066301
# sample number 211 entropy 2.53593402779
# sample number 212 entropy 2.53240430704
# sample number 213 entropy 2.5241955563
# sample number 214 entropy 2.53545131298
# sample number 215 entropy 2.535075607
# sample number 216 entropy 2.53340015826
# sample number 217 entropy 2.53491647197
# sample number 218 entropy 2.53583757743
# sample number 219 entropy 2.53358591582
# sample number 220 entropy 2.53554174977
# sample number 221 entropy 2.4894959878
# sample number 222 entropy 2.53558983262
# sample number 223 entropy 2.53587990258
# sample number 224 entropy 2.41255865399
# sample number 225 entropy 2.53482196579
# sample number 226 entropy 2.53487093869
# sample number 227 entropy 2.53555267715
# sample number 228 entropy 2.53474444729
# sample number 229 entropy 2.53241265203
# sample number 230 entropy 2.53584063978
# sample number 231 entropy 2.53403730543
# sample number 232 entropy 2.5357073615
# sample number 233 entropy 2.53560748184
# sample number 234 entropy 2.53564217872
# sample number 235 entropy 2.534124497
# sample number 236 entropy 2.53563892969
# sample number 237 entropy 2.53431587848
# sample number 238 entropy 2.5357447131
# sample number 239 entropy 2.53416647375
# sample number 240 entropy 2.53475580621
# sample number 241 entropy 2.51127374473
# sample number 242 entropy 2.53505729881
# sample number 243 entropy 2.53572054763
# sample number 244 entropy 2.53517471715
# sample number 245 entropy 2.53551339771
# sample number 246 entropy 2.4287739343
# sample number 247 entropy 2.53588528392
# sample number 248 entropy 2.534439345
# sample number 249 entropy 2.53528851625
# sample number 250 entropy 2.53447816899
# sample number 251 entropy 2.45218325133
# sample number 252 entropy 2.53507202959
# sample number 253 entropy 2.53348478914
# sample number 254 entropy 2.53488484847
# sample number 255 entropy 2.53588857437
# sample number 256 entropy 2.53520206355
# sample number 257 entropy 2.53464848368
# sample number 258 entropy 2.53507900503
# sample number 259 entropy 2.53347450856
# sample number 260 entropy 2.5307191384
# sample number 261 entropy 2.53580001388
# sample number 262 entropy 2.53535025041
# sample number 263 entropy 2.5308930246
# sample number 264 entropy 2.45830482286
# sample number 265 entropy 2.48442508951
# sample number 266 entropy 2.53577809158
# sample number 267 entropy 2.53540863252
# sample number 268 entropy 2.53593279071
# sample number 269 entropy 2.53564846184
# sample number 270 entropy 2.53407551768
# sample number 271 entropy 2.53321184911
# sample number 272 entropy 2.47080151543
# sample number 273 entropy 2.53590031956
# sample number 274 entropy 2.53527153567
# sample number 275 entropy 2.53571404206
# sample number 276 entropy 2.53548029739
# sample number 277 entropy 2.44299920866
# sample number 278 entropy 2.53586627697
# sample number 279 entropy 2.53334101867
# sample number 280 entropy 2.53579921681
# sample number 281 entropy 2.53476498186
# sample number 282 entropy 2.53550758756
# sample number 283 entropy 2.5346502687
# sample number 284 entropy 2.44500708103
# sample number 285 entropy 2.5353955608
# sample number 286 entropy 2.53509452227
# sample number 287 entropy 2.53495229211
# sample number 288 entropy 2.53435055476
# sample number 289 entropy 2.53487722375
# sample number 290 entropy 2.53561397031
# sample number 291 entropy 2.53563060459
# sample number 292 entropy 2.53379675393
# sample number 293 entropy 2.53538711064
# sample number 294 entropy 2.53581852103
# sample number 295 entropy 2.46137753938
# sample number 296 entropy 2.5209413082
# sample number 297 entropy 2.534714654
# sample number 298 entropy 2.53544475278
# sample number 299 entropy 2.43069912445
# number of variables 3
# goal entropy 3.80391000173
# sample number 200 entropy 3.80193758208
# sample number 201 entropy 3.80360252821
# sample number 202 entropy 3.80256785598
# sample number 203 entropy 3.80384790517
# sample number 204 entropy 3.80292361255
# sample number 205 entropy 3.80338546778
# sample number 206 entropy 3.8012239866
# sample number 207 entropy 3.8037722359
# sample number 208 entropy 3.80249377555
# sample number 209 entropy 3.80360637441
# sample number 210 entropy 3.80366521717
# sample number 211 entropy 3.80364341695
# sample number 212 entropy 3.80294482394
# sample number 213 entropy 3.80351196475
# sample number 214 entropy 3.80353648385
# sample number 215 entropy 3.80377927133
# sample number 216 entropy 3.80379911249
# sample number 217 entropy 3.80388363928
# sample number 218 entropy 3.80369695195
# sample number 219 entropy 3.80214154746
# sample number 220 entropy 3.77979960483
# sample number 221 entropy 3.80320382672
# sample number 222 entropy 3.80334106436
# sample number 223 entropy 3.80385725402
# sample number 224 entropy 3.80233783939
# sample number 225 entropy 3.80389279202
# sample number 226 entropy 3.80366337065
# sample number 227 entropy 3.80361482444
# sample number 228 entropy 3.80013694972
# sample number 229 entropy 3.80277150148
# sample number 230 entropy 3.80377473428
# sample number 231 entropy 3.80376899335
# sample number 232 entropy 3.79994623
# sample number 233 entropy 3.80284629603
# sample number 234 entropy 3.80330354054
# sample number 235 entropy 3.80201179639
# sample number 236 entropy 3.80326187202
# sample number 237 entropy 3.80377773402
# sample number 238 entropy 3.8037131798
# sample number 239 entropy 3.80387770716
# sample number 240 entropy 3.80342114837
# sample number 241 entropy 3.80332750825
# sample number 242 entropy 3.80384140394
# sample number 243 entropy 3.80364146935
# sample number 244 entropy 3.80309455582
# sample number 245 entropy 3.80330318622
# sample number 246 entropy 3.80365074288
# sample number 247 entropy 3.80214708931
# sample number 248 entropy 3.80273520889
# sample number 249 entropy 3.80301477087
# sample number 250 entropy 3.80384162223
# sample number 251 entropy 3.8028380881
# sample number 252 entropy 3.80186755026
# sample number 253 entropy 3.80325868085
# sample number 254 entropy 3.80117861253
# sample number 255 entropy 3.80195827475
# sample number 256 entropy 3.80390204282
# sample number 257 entropy 3.80146729772
# sample number 258 entropy 3.80384741659
# sample number 259 entropy 3.79996711052
# sample number 260 entropy 3.80363640372
# sample number 261 entropy 3.80342075997
# sample number 262 entropy 3.80389158857
# sample number 263 entropy 3.80368430943
# sample number 264 entropy 3.80376392085
# sample number 265 entropy 3.801903936
# sample number 266 entropy 3.80189785769
# sample number 267 entropy 3.80345925388
# sample number 268 entropy 3.80239224937
# sample number 269 entropy 3.80300264507
# sample number 270 entropy 3.80230858547
# sample number 271 entropy 3.80341606945
# sample number 272 entropy 3.8035905918
# sample number 273 entropy 3.8030038378
# sample number 274 entropy 3.80353079992
# sample number 275 entropy 3.80125658354
# sample number 276 entropy 3.80390935883
# sample number 277 entropy 3.80353023547
# sample number 278 entropy 3.8037951378
# sample number 279 entropy 3.80316075071
# sample number 280 entropy 3.80311461189
# sample number 281 entropy 3.80388345819
# sample number 282 entropy 3.80187572799
# sample number 283 entropy 3.80372487521
# sample number 284 entropy 3.80354036826
# sample number 285 entropy 3.80298884161
# sample number 286 entropy 3.80139804695
# sample number 287 entropy 3.80186400325
# sample number 288 entropy 3.80381011547
# sample number 289 entropy 3.8011283417
# sample number 290 entropy 3.80159192341
# sample number 291 entropy 3.80328564891
# sample number 292 entropy 3.80339247651
# sample number 293 entropy 3.80309290366
# sample number 294 entropy 3.80337816601
# sample number 295 entropy 3.80248598885
# sample number 296 entropy 3.80357077041
# sample number 297 entropy 3.8035993752
# sample number 298 entropy 3.80208241158
# sample number 299 entropy 3.80387622505
# number of variables 4
# goal entropy 5.07188000231
# sample number 200 entropy 5.07116834059
# sample number 201 entropy 5.07073738007
# sample number 202 entropy 5.07077123965
# sample number 203 entropy 5.06859640498
# sample number 204 entropy 5.07167192385
# sample number 205 entropy 5.07171243283
# sample number 206 entropy 5.07166906164
# sample number 207 entropy 5.07101416457
# sample number 208 entropy 5.06984159394
# sample number 209 entropy 5.07067679852
# sample number 210 entropy 5.07073604846
# sample number 211 entropy 5.07114390481
# sample number 212 entropy 5.07181339663
# sample number 213 entropy 5.07153899495
# sample number 214 entropy 5.07110026836
# sample number 215 entropy 5.07013679569
# sample number 216 entropy 5.07177264297
# sample number 217 entropy 5.07114917181
# sample number 218 entropy 5.07137185911
# sample number 219 entropy 5.07063822349
# sample number 220 entropy 5.06926286161
# sample number 221 entropy 5.0713679979
# sample number 222 entropy 5.06847095705
# sample number 223 entropy 5.06690690261
# sample number 224 entropy 5.06805886951
# sample number 225 entropy 5.07150467642
# sample number 226 entropy 5.07156043211
# sample number 227 entropy 5.07117453649
# sample number 228 entropy 5.07180235168
# sample number 229 entropy 5.07112769819
# sample number 230 entropy 5.07183907251
# sample number 231 entropy 5.07182346638
# sample number 232 entropy 5.07112028375
# sample number 233 entropy 5.07153858307
# sample number 234 entropy 5.07187499869
# sample number 235 entropy 5.07051830574
# sample number 236 entropy 5.07161419486
# sample number 237 entropy 5.07164382659
# sample number 238 entropy 5.07178958378
# sample number 239 entropy 5.07151200572
# sample number 240 entropy 5.0715943253
# sample number 241 entropy 5.07140791239
# sample number 242 entropy 5.07169503471
# sample number 243 entropy 5.07132431112
# sample number 244 entropy 5.07023031469
# sample number 245 entropy 5.07035681364
# sample number 246 entropy 5.07118904733
# sample number 247 entropy 5.0715934621
# sample number 248 entropy 5.071604167
# sample number 249 entropy 5.07174627147
# sample number 250 entropy 5.07187266456
# sample number 251 entropy 5.07044151755
# sample number 252 entropy 5.07183151245
# sample number 253 entropy 5.07143218041
# sample number 254 entropy 5.07161829357
# sample number 255 entropy 5.07185160704
# sample number 256 entropy 5.06880948604
# sample number 257 entropy 5.07049426902
# sample number 258 entropy 5.07074547883
# sample number 259 entropy 5.07173073439
# sample number 260 entropy 5.07084372617
# sample number 261 entropy 5.07170368798
# sample number 262 entropy 5.07143027126
# sample number 263 entropy 5.07055379178
# sample number 264 entropy 5.07119643654
# sample number 265 entropy 5.07015113248
# sample number 266 entropy 5.07173582482
# sample number 267 entropy 5.07082506058
# sample number 268 entropy 5.07170167709
# sample number 269 entropy 5.07083612696
# sample number 270 entropy 5.07167601543
# sample number 271 entropy 5.07177983571
# sample number 272 entropy 5.07179599556
# sample number 273 entropy 5.0714692649
# sample number 274 entropy 5.07000281988
# sample number 275 entropy 5.07156435562
# sample number 276 entropy 5.06967409255
# sample number 277 entropy 5.07122772467
# sample number 278 entropy 5.07120089524
# sample number 279 entropy 5.07172784379
# sample number 280 entropy 5.0712906043
# sample number 281 entropy 5.07149906827
# sample number 282 entropy 5.07168690692
# sample number 283 entropy 5.07093906898
# sample number 284 entropy 5.0716100771
# sample number 285 entropy 5.07173749538
# sample number 286 entropy 5.07145849085
# sample number 287 entropy 5.06732546846
# sample number 288 entropy 5.07132320818
# sample number 289 entropy 5.07087298102
# sample number 290 entropy 5.07123126561
# sample number 291 entropy 5.07150880498
# sample number 292 entropy 5.07159221656
# sample number 293 entropy 5.07031618309
# sample number 294 entropy 5.07080314084
# sample number 295 entropy 5.07181540995
# sample number 296 entropy 5.07172036128
# sample number 297 entropy 5.07183345152
# sample number 298 entropy 5.07177800295
# sample number 299 entropy 5.07010413774
# number of variables 5
# goal entropy 6.33985000288
# sample number 200 entropy 6.33613159341
# sample number 201 entropy 6.33801506112
# sample number 202 entropy 6.33892923552
# sample number 203 entropy 6.33963565282
# sample number 204 entropy 6.33875233972
# sample number 205 entropy 6.33872579693
# sample number 206 entropy 6.33939545628
# sample number 207 entropy 6.33940163658
# sample number 208 entropy 6.3398008414
# sample number 209 entropy 6.33906942484
# sample number 210 entropy 6.33953670535
# sample number 211 entropy 6.33963666839
# sample number 212 entropy 6.33982452264
# sample number 213 entropy 6.33921747536
# sample number 214 entropy 6.33960053661
# sample number 215 entropy 6.33917362998
# sample number 216 entropy 6.33812034688
# sample number 217 entropy 6.33955753597
# sample number 218 entropy 6.33945281116
# sample number 219 entropy 6.33895710267
# sample number 220 entropy 6.33928158358
# sample number 221 entropy 6.33969090782
# sample number 222 entropy 6.33886218387
# sample number 223 entropy 6.33940726251
# sample number 224 entropy 6.33860690245
# sample number 225 entropy 6.33826972072
# sample number 226 entropy 6.33965669202
# sample number 227 entropy 6.33923523007
# sample number 228 entropy 6.33961507243
# sample number 229 entropy 6.33968804174
# sample number 230 entropy 6.33971284986
# sample number 231 entropy 6.33982829537
# sample number 232 entropy 6.33971558157
# sample number 233 entropy 6.33927757509
# sample number 234 entropy 6.33813214543
# sample number 235 entropy 6.3393369236
# sample number 236 entropy 6.33768028311
# sample number 237 entropy 6.33970503956
# sample number 238 entropy 6.33971091865
# sample number 239 entropy 6.33900399578
# sample number 240 entropy 6.33948562803
# sample number 241 entropy 6.3397895027
# sample number 242 entropy 6.33944302414
# sample number 243 entropy 6.3393099037
# sample number 244 entropy 6.33979002312
# sample number 245 entropy 6.33980809766
# sample number 246 entropy 6.33982299291
# sample number 247 entropy 6.33858022475
# sample number 248 entropy 6.33934403643
# sample number 249 entropy 6.33914085643
# sample number 250 entropy 6.33972789716
# sample number 251 entropy 6.33957123697
# sample number 252 entropy 6.3386191144
# sample number 253 entropy 6.33936666898
# sample number 254 entropy 6.33982734002
# sample number 255 entropy 6.33982332359
# sample number 256 entropy 6.33929267139
# sample number 257 entropy 6.33889334757
# sample number 258 entropy 6.33967896557
# sample number 259 entropy 6.3397445227
# sample number 260 entropy 6.33934480326
# sample number 261 entropy 6.33916351337
# sample number 262 entropy 6.33914025122
# sample number 263 entropy 6.33877567361
# sample number 264 entropy 6.33856885384
# sample number 265 entropy 6.3395576014
# sample number 266 entropy 6.33955153531
# sample number 267 entropy 6.33943723305
# sample number 268 entropy 6.33763189425
# sample number 269 entropy 6.3397650071
# sample number 270 entropy 6.33924723888
# sample number 271 entropy 6.33860843709
# sample number 272 entropy 6.33909044092
# sample number 273 entropy 6.3374118541
# sample number 274 entropy 6.3397374238
# sample number 275 entropy 6.33969912043
# sample number 276 entropy 6.33797362582
# sample number 277 entropy 6.33925279218
# sample number 278 entropy 6.33979388794
# sample number 279 entropy 6.33895790527
# sample number 280 entropy 6.33878151935
# sample number 281 entropy 6.33878002298
# sample number 282 entropy 6.33949818182
# sample number 283 entropy 6.33728661517
# sample number 284 entropy 6.33933101056
# sample number 285 entropy 6.33918315508
# sample number 286 entropy 6.33956768894
# sample number 287 entropy 6.33941637435
# sample number 288 entropy 6.33928287555
# sample number 289 entropy 6.33984474178
# sample number 290 entropy 6.33856035077
# sample number 291 entropy 6.33921551259
# sample number 292 entropy 6.33979866768
# sample number 293 entropy 6.33935366672
# sample number 294 entropy 6.33924437302
# sample number 295 entropy 6.33653200916
# sample number 296 entropy 6.33769696672
# sample number 297 entropy 6.33846601563
# sample number 298 entropy 6.33853982337
# sample number 299 entropy 6.33936703739
# number of variables 6
# goal entropy 7.60782000346
# sample number 200 entropy 7.60778389954
# sample number 201 entropy 7.60596709962
# sample number 202 entropy 7.60774485678
# sample number 203 entropy 7.60778178162
# sample number 204 entropy 7.60758943623
# sample number 205 entropy 7.60676495603
# sample number 206 entropy 7.60555427996
# sample number 207 entropy 7.60771650395
# sample number 208 entropy 7.60760331349
# sample number 209 entropy 7.60540934685
# sample number 210 entropy 7.60776691929
# sample number 211 entropy 7.60753096683
# sample number 212 entropy 7.60636595223
# sample number 213 entropy 7.60763067604
# sample number 214 entropy 7.6056340122
# sample number 215 entropy 7.60677940863
# sample number 216 entropy 7.60723536217
# sample number 217 entropy 7.60747686112
# sample number 218 entropy 7.60737172577
# sample number 219 entropy 7.60646833682
# sample number 220 entropy 7.60732188071
# sample number 221 entropy 7.6075808773
# sample number 222 entropy 7.60646472636
# sample number 223 entropy 7.6072771581
# sample number 224 entropy 7.60738173754
# sample number 225 entropy 7.60703450839
# sample number 226 entropy 7.60769889961
# sample number 227 entropy 7.6070045849
# sample number 228 entropy 7.60781741484
# sample number 229 entropy 7.60767951272
# sample number 230 entropy 7.60729705896
# sample number 231 entropy 7.60774288421
# sample number 232 entropy 7.60721807574
# sample number 233 entropy 7.60777151458
# sample number 234 entropy 7.60722234741
# sample number 235 entropy 7.60765876241
# sample number 236 entropy 7.60750544559
# sample number 237 entropy 7.6077479837
# sample number 238 entropy 7.60761174028
# sample number 239 entropy 7.60575652877
# sample number 240 entropy 7.6078174807
# sample number 241 entropy 7.60772900627
# sample number 242 entropy 7.60535571178
# sample number 243 entropy 7.60701554578
# sample number 244 entropy 7.60709359697
# sample number 245 entropy 7.60776015769
# sample number 246 entropy 7.6064157618
# sample number 247 entropy 7.60774204639
# sample number 248 entropy 7.60521955846
# sample number 249 entropy 7.60767900613
# sample number 250 entropy 7.60779373374
# sample number 251 entropy 7.60744947948
# sample number 252 entropy 7.60638005609
# sample number 253 entropy 7.60691980782
# sample number 254 entropy 7.60779577316
# sample number 255 entropy 7.60767864778
# sample number 256 entropy 7.60667612888
# sample number 257 entropy 7.60757538704
# sample number 258 entropy 7.60745164512
# sample number 259 entropy 7.60702466829
# sample number 260 entropy 7.6069080838
# sample number 261 entropy 7.60634771425
# sample number 262 entropy 7.60678753225
# sample number 263 entropy 7.60770890384
# sample number 264 entropy 7.60525177306
# sample number 265 entropy 7.60779833146
# sample number 266 entropy 7.60735736584
# sample number 267 entropy 7.60743792836
# sample number 268 entropy 7.60714335182
# sample number 269 entropy 7.60745200809
# sample number 270 entropy 7.60651226127
# sample number 271 entropy 7.60679102023
# sample number 272 entropy 7.60755436373
# sample number 273 entropy 7.60771674001
# sample number 274 entropy 7.60770717564
# sample number 275 entropy 7.60757160504
# sample number 276 entropy 7.60753695549
# sample number 277 entropy 7.60521080675
# sample number 278 entropy 7.60737013784
# sample number 279 entropy 7.60718702416
# sample number 280 entropy 7.60740203719
# sample number 281 entropy 7.60670423462
# sample number 282 entropy 7.60711048729
# sample number 283 entropy 7.60768931097
# sample number 284 entropy 7.60740436572
# sample number 285 entropy 7.60777780179
# sample number 286 entropy 7.60781517771
# sample number 287 entropy 7.60739095404
# sample number 288 entropy 7.60717981928
# sample number 289 entropy 7.60515154898
# sample number 290 entropy 7.60715447096
# sample number 291 entropy 7.60749474453
# sample number 292 entropy 7.60668708433
# sample number 293 entropy 7.60718548249
# sample number 294 entropy 7.60728343878
# sample number 295 entropy 7.60775554232
# sample number 296 entropy 7.60641040572
# sample number 297 entropy 7.60587589967
# sample number 298 entropy 7.60728663067
# sample number 299 entropy 7.60682481228
# number of variables 7
# goal entropy 8.87579000404
# sample number 200 entropy 8.87554372732
# sample number 201 entropy 8.8753327244
# sample number 202 entropy 8.87577106656
# sample number 203 entropy 8.87366425965
# sample number 204 entropy 8.87570902716
# sample number 205 entropy 8.87535839713
# sample number 206 entropy 8.8737040066
# sample number 207 entropy 8.8737503371
# sample number 208 entropy 8.87564377724
# sample number 209 entropy 8.87542712064
# sample number 210 entropy 8.87569403793
# sample number 211 entropy 8.87392898066
# sample number 212 entropy 8.87469635645
# sample number 213 entropy 8.87539342373
# sample number 214 entropy 8.87547264266
# sample number 215 entropy 8.8756998141
# sample number 216 entropy 8.87577202185
# sample number 217 entropy 8.87559527521
# sample number 218 entropy 8.8737425651
# sample number 219 entropy 8.87522954921
# sample number 220 entropy 8.87525952486
# sample number 221 entropy 8.87571087659
# sample number 222 entropy 8.87526731866
# sample number 223 entropy 8.87508552375
# sample number 224 entropy 8.87578352738
# sample number 225 entropy 8.87576886388
# sample number 226 entropy 8.87436509478
# sample number 227 entropy 8.87513532214
# sample number 228 entropy 8.87578851069
# sample number 229 entropy 8.87531948483
# sample number 230 entropy 8.87571006198
# sample number 231 entropy 8.87520436539
# sample number 232 entropy 8.87530523034
# sample number 233 entropy 8.87517479291
# sample number 234 entropy 8.87571418065
# sample number 235 entropy 8.87565404084
# sample number 236 entropy 8.87556448701
# sample number 237 entropy 8.8756849369
# sample number 238 entropy 8.87529685742
# sample number 239 entropy 8.87485663251
# sample number 240 entropy 8.87506853008
# sample number 241 entropy 8.87506272554
# sample number 242 entropy 8.87541515447
# sample number 243 entropy 8.87559256137
# sample number 244 entropy 8.87549631785
# sample number 245 entropy 8.87578430312
# sample number 246 entropy 8.87484437918
# sample number 247 entropy 8.87502559925
# sample number 248 entropy 8.87384050442
# sample number 249 entropy 8.87546467133
# sample number 250 entropy 8.87552667782
# sample number 251 entropy 8.8751436361
# sample number 252 entropy 8.8757073827
# sample number 253 entropy 8.87558632984
# sample number 254 entropy 8.87474261346
# sample number 255 entropy 8.87522461356
# sample number 256 entropy 8.87568545416
# sample number 257 entropy 8.87577975514
# sample number 258 entropy 8.87572898022
# sample number 259 entropy 8.87561036835
# sample number 260 entropy 8.87556865531
# sample number 261 entropy 8.87548492611
# sample number 262 entropy 8.8752795095
# sample number 263 entropy 8.87577113367
# sample number 264 entropy 8.8754671031
# sample number 265 entropy 8.87490485544
# sample number 266 entropy 8.87538357334
# sample number 267 entropy 8.87524083066
# sample number 268 entropy 8.87530272131
# sample number 269 entropy 8.8757853022
# sample number 270 entropy 8.87542276626
# sample number 271 entropy 8.87557933188
# sample number 272 entropy 8.87545792235
# sample number 273 entropy 8.87515373065
# sample number 274 entropy 8.87513870486
# sample number 275 entropy 8.87523782863
# sample number 276 entropy 8.87456034289
# sample number 277 entropy 8.87504757589
# sample number 278 entropy 8.87573608532
# sample number 279 entropy 8.87572411321
# sample number 280 entropy 8.87516855175
# sample number 281 entropy 8.87575751662
# sample number 282 entropy 8.87576451283
# sample number 283 entropy 8.87467386078
# sample number 284 entropy 8.87516808027
# sample number 285 entropy 8.87574618099
# sample number 286 entropy 8.87577889611
# sample number 287 entropy 8.87544148117
# sample number 288 entropy 8.87570520002
# sample number 289 entropy 8.87562644747
# sample number 290 entropy 8.87538587652
# sample number 291 entropy 8.87561919516
# sample number 292 entropy 8.87577691443
# sample number 293 entropy 8.87556363777
# sample number 294 entropy 8.87548921558
# sample number 295 entropy 8.8756884316
# sample number 296 entropy 8.87577843608
# sample number 297 entropy 8.87550415727
# sample number 298 entropy 8.87541321252
# sample number 299 entropy 8.87553495152

# %% [markdown]
# #### From the joint distribution take the input distribution (the marginal of the first N-1 axis) and the output (the Nth axis) conditioned on the input

# %%
TEST = True
RUN = True
limited_entropy.PRINT = False

evolutionary_params_generate_conditional_output_stats = {
    "number_of_generations": 700,
    "population_size": 20,
    "number_of_children": 80,
    "generational": False,
    "mutation_method": "step_wise_after",
    "number_of_mutations": 3,
    "mutation_size": 0.01,
    "parent_selection_mode": "rank_exponential",
    "early_stopping_criterium": 0.01
}

def produce_conditional_states(entropy_size, evolution_params, number_of_states=NUMBER_OF_STATES):
    while True:
        new_entropy_size = entropy_size + np.random.uniform(-0.15*entropy_size, 0.15*entropy_size) 
        yield limited_entropy.get_dist_with_entropy(
            NUMBER_OF_STATES, new_entropy_size, 
            evolution_params, verbose=False    
        )

if RUN:
    min_number_of_variables = max(MIN_NUMBER_VARIABLES, 2)
    for number_of_variables in range(min_number_of_variables, MAX_NUMBER_VARIABLES+1, 1):
        print("number of variables {}".format(number_of_variables))
        directory = (
            PATH + TOP_FOLDER + FOLDER_PERCENTAGE_MAX_ENTROPY
            + FOLDER_DISTRIBUTION_SHAPE_FORMAT.format(number_of_variables, NUMBER_OF_STATES)
        )
        dist_shape = [NUMBER_OF_STATES]*number_of_variables
        input_labels = set(range(number_of_variables-1))
        output_label = set([number_of_variables-1])
        for sample_number in range(START_NUMBER_SAMPLES, END_NUMBER_SAMPLES, 1):
            print("sample number {}".format(sample_number))
            #load the distribution
            file_name = FILENAME_DISTRIBUTION_FORMAT.format(sample_number)
            with open(directory+file_name, 'rb') as f:
                joint = np.load(f)
                
            #produce the marginal
            joint_dist = probability_distributions.ProbabilityArray(joint)
            input_dist = joint_dist.marginalize(input_labels)
            
            #save the marginal (representing the input distribution)
            file_name = FILENAME_INPUT_FORMAT.format(sample_number)
            with open(directory+file_name, 'wb') as f:
                np.save(f, input_dist)
                
            print("number of input states with zero probability {}".format(
                input_dist.flatten().shape[0]-np.count_nonzero(input_dist.flatten())
            ))
            
            #produce the conditional output
            entropies = [stats.entropy(joint[tuple(state)], base=2) for state in np.argwhere(input_dist != 0)]
            average_entropy = np.mean(entropies)
            print(average_entropy)
            generator = produce_conditional_states(
                average_entropy, evolutionary_params_generate_conditional_output_stats
            )
            cond_output , mar_labels, cond_labels = joint_dist.find_conditional_accounting_for_zero_marginals(
                output_label, input_labels, generator
            )
            
            #save cond_output
            file_name = FILENAME_COND_OUTPUT_FORMAT.format(sample_number)
            with open(directory+file_name, 'wb') as f:
                np.save(f, cond_output)
                
            if TEST:
                computed_joint = probability_distributions.compute_joint(input_dist, cond_output, cond_labels)
                if not np.allclose(computed_joint, joint):
                    raise ValueError()
# Out:
# number of variables 2
# sample number 200
# number of input states with zero probability 0
# 1.00005059015
# sample number 201
# number of input states with zero probability 0
# 0.981237823469
# sample number 202
# number of input states with zero probability 0
# 0.963020676566
# sample number 203
# number of input states with zero probability 0
# 1.10271391173
# sample number 204
# number of input states with zero probability 0
# 1.06145741041
# sample number 205
# number of input states with zero probability 0
# 0.930167473679
# sample number 206
# number of input states with zero probability 0
# 1.06200674144
# sample number 207
# number of input states with zero probability 0
# 0.957207234523
# sample number 208
# number of input states with zero probability 0
# 0.915068297698
# sample number 209
# number of input states with zero probability 0
# 1.04139418811
# sample number 210
# number of input states with zero probability 0
# 1.04139751083
# sample number 211
# number of input states with zero probability 0
# 0.91806897775
# sample number 212
# number of input states with zero probability 0
# 1.37401416549
# sample number 213
# number of input states with zero probability 0
# 1.09931922738
# sample number 214
# number of input states with zero probability 0
# 0.936144817585
# sample number 215
# number of input states with zero probability 0
# 0.988859670667
# sample number 216
# number of input states with zero probability 0
# 1.07101606139
# sample number 217
# number of input states with zero probability 0
# 0.865033670491
# sample number 218
# number of input states with zero probability 0
# 0.921518607619
# sample number 219
# number of input states with zero probability 0
# 0.988978794441
# sample number 220
# number of input states with zero probability 0
# 1.13695356493
# sample number 221
# number of input states with zero probability 0
# 1.13859769228
# sample number 222
# number of input states with zero probability 0
# 1.05660585346
# sample number 223
# number of input states with zero probability 0
# 0.995148908059
# sample number 224
# number of input states with zero probability 0
# 0.959036367425
# sample number 225
# number of input states with zero probability 0
# 0.92881194613
# sample number 226
# number of input states with zero probability 0
# 1.02329146715
# sample number 227
# number of input states with zero probability 0
# 0.971880478472
# sample number 228
# number of input states with zero probability 0
# 1.00038760076
# sample number 229
# number of input states with zero probability 0
# 0.942098838557
# sample number 230
# number of input states with zero probability 0
# 1.06627850568
# sample number 231
# number of input states with zero probability 0
# 1.14531548718
# sample number 232
# number of input states with zero probability 0
# 0.90638142638
# sample number 233
# number of input states with zero probability 0
# 0.963570848164
# sample number 234
# number of input states with zero probability 0
# 1.29707599307
# sample number 235
# number of input states with zero probability 0
# 1.13656586947
# sample number 236
# number of input states with zero probability 0
# 1.10239237488
# sample number 237
# number of input states with zero probability 0
# 0.916964888142
# sample number 238
# number of input states with zero probability 0
# 1.00276526102
# sample number 239
# number of input states with zero probability 0
# 1.00448389868
# sample number 240
# number of input states with zero probability 0
# 1.16274148747
# sample number 241
# number of input states with zero probability 0
# 0.935684583121
# sample number 242
# number of input states with zero probability 0
# 1.15232173852
# sample number 243
# number of input states with zero probability 0
# 1.11734555058
# sample number 244
# number of input states with zero probability 0
# 1.00227936421
# sample number 245
# number of input states with zero probability 0
# 1.0572864809
# sample number 246
# number of input states with zero probability 0
# 0.839030507737
# sample number 247
# number of input states with zero probability 0
# 1.03165166254
# sample number 248
# number of input states with zero probability 0
# 1.09034582057
# sample number 249
# number of input states with zero probability 0
# 1.14664605013
# sample number 250
# number of input states with zero probability 0
# 1.15895451296
# sample number 251
# number of input states with zero probability 0
# 1.05955513863
# sample number 252
# number of input states with zero probability 0
# 1.0675398545
# sample number 253
# number of input states with zero probability 0
# 0.934125967612
# sample number 254
# number of input states with zero probability 0
# 0.958727004606
# sample number 255
# number of input states with zero probability 0
# 1.08374604058
# sample number 256
# number of input states with zero probability 0
# 0.9180118654
# sample number 257
# number of input states with zero probability 0
# 1.14625788222
# sample number 258
# number of input states with zero probability 0
# 1.36055013785
# sample number 259
# number of input states with zero probability 0
# 1.16334242668
# sample number 260
# number of input states with zero probability 0
# 1.14656282244
# sample number 261
# number of input states with zero probability 0
# 1.01550135315
# sample number 262
# number of input states with zero probability 0
# 1.07842952486
# sample number 263
# number of input states with zero probability 0
# 0.954667091336
# sample number 264
# number of input states with zero probability 0
# 0.946015186971
# sample number 265
# number of input states with zero probability 0
# 1.04174593358
# sample number 266
# number of input states with zero probability 0
# 1.14174452398
# sample number 267
# number of input states with zero probability 0
# 0.946124477385
# sample number 268
# number of input states with zero probability 0
# 0.903639169563
# sample number 269
# number of input states with zero probability 0
# 1.02437329795
# sample number 270
# number of input states with zero probability 0
# 1.01771185576
# sample number 271
# number of input states with zero probability 0
# 0.81476520088
# sample number 272
# number of input states with zero probability 0
# 1.11232361306
# sample number 273
# number of input states with zero probability 0
# 0.922871046076
# sample number 274
# number of input states with zero probability 0
# 1.03349912899
# sample number 275
# number of input states with zero probability 0
# 1.19633092299
# sample number 276
# number of input states with zero probability 0
# 0.916929720162
# sample number 277
# number of input states with zero probability 0
# 0.885706282809
# sample number 278
# number of input states with zero probability 0
# 1.24465782975
# sample number 279
# number of input states with zero probability 0
# 0.984957903145
# sample number 280
# number of input states with zero probability 0
# 1.26121487815
# sample number 281
# number of input states with zero probability 0
# 0.964558454173
# sample number 282
# number of input states with zero probability 0
# 0.961719061261
# sample number 283
# number of input states with zero probability 0
# 0.945832596121
# sample number 284
# number of input states with zero probability 0
# 1.24329894853
# sample number 285
# number of input states with zero probability 0
# 1.05226213948
# sample number 286
# number of input states with zero probability 0
# 0.999745364885
# sample number 287
# number of input states with zero probability 0
# 1.33522466174
# sample number 288
# number of input states with zero probability 0
# 1.07222175454
# sample number 289
# number of input states with zero probability 0
# 1.07781631131
# sample number 290
# number of input states with zero probability 0
# 0.957076295121
# sample number 291
# number of input states with zero probability 0
# 0.979727876814
# sample number 292
# number of input states with zero probability 0
# 0.950155032155
# sample number 293
# number of input states with zero probability 0
# 1.01149010623
# sample number 294
# number of input states with zero probability 0
# 1.02107605283
# sample number 295
# number of input states with zero probability 0
# 1.13397265282
# sample number 296
# number of input states with zero probability 0
# 0.993158123432
# sample number 297
# number of input states with zero probability 0
# 0.920197378167
# sample number 298
# number of input states with zero probability 0
# 1.02874352172
# sample number 299
# number of input states with zero probability 0
# 1.15709460736
# number of variables 3
# sample number 200
# number of input states with zero probability 0
# 0.633557181242
# sample number 201
# number of input states with zero probability 0
# 0.727723143035
# sample number 202
# number of input states with zero probability 0
# 0.779024293157
# sample number 203
# number of input states with zero probability 0
# 0.741800270821
# sample number 204
# number of input states with zero probability 0
# 0.702154851091
# sample number 205
# number of input states with zero probability 0
# 0.784498215052
# sample number 206
# number of input states with zero probability 0
# 0.820770999051
# sample number 207
# number of input states with zero probability 0
# 0.912558435576
# sample number 208
# number of input states with zero probability 0
# 0.720856880726
# sample number 209
# number of input states with zero probability 0
# 0.871979082437
# sample number 210
# number of input states with zero probability 0
# 0.863387133911
# sample number 211
# number of input states with zero probability 0
# 0.859335973638
# sample number 212
# number of input states with zero probability 0
# 1.20319914873
# sample number 213
# number of input states with zero probability 0
# 0.66097572249
# sample number 214
# number of input states with zero probability 0
# 0.920533621257
# sample number 215
# number of input states with zero probability 0
# 0.683058025291
# sample number 216
# number of input states with zero probability 0
# 0.754704812202
# sample number 217
# number of input states with zero probability 0
# 0.936444755337
# sample number 218
# number of input states with zero probability 0
# 1.00122080806
# sample number 219
# number of input states with zero probability 0
# 0.905727851763
# sample number 220
# number of input states with zero probability 0
# 1.0648805937
# sample number 221
# number of input states with zero probability 0
# 0.753703204713
# sample number 222
# number of input states with zero probability 0
# 0.911329175855
# sample number 223
# number of input states with zero probability 0
# 0.735812731648
# sample number 224
# number of input states with zero probability 0
# 0.73423472051
# sample number 225
# number of input states with zero probability 0
# 0.868648739454
# sample number 226
# number of input states with zero probability 0
# 0.860386711527
# sample number 227
# number of input states with zero probability 0
# 0.688833546821
# sample number 228
# number of input states with zero probability 0
# 1.07695367627
# sample number 229
# number of input states with zero probability 0
# 0.981584945265
# sample number 230
# number of input states with zero probability 0
# 0.728886999555
# sample number 231
# number of input states with zero probability 0
# 0.693967771905
# sample number 232
# number of input states with zero probability 0
# 0.775303592223
# sample number 233
# number of input states with zero probability 0
# 0.672335348268
# sample number 234
# number of input states with zero probability 0
# 0.782553001338
# sample number 235
# number of input states with zero probability 0
# 0.883270105482
# sample number 236
# number of input states with zero probability 0
# 0.831880449335
# sample number 237
# number of input states with zero probability 0
# 0.815517416921
# sample number 238
# number of input states with zero probability 0
# 0.767359101673
# sample number 239
# number of input states with zero probability 0
# 0.930587189123
# sample number 240
# number of input states with zero probability 0
# 0.916043523643
# sample number 241
# number of input states with zero probability 0
# 0.782153003811
# sample number 242
# number of input states with zero probability 0
# 0.739939869868
# sample number 243
# number of input states with zero probability 0
# 0.908603781203
# sample number 244
# number of input states with zero probability 0
# 0.688617293699
# sample number 245
# number of input states with zero probability 0
# 0.725501205128
# sample number 246
# number of input states with zero probability 0
# 0.695475846871
# sample number 247
# number of input states with zero probability 0
# 1.02725097717
# sample number 248
# number of input states with zero probability 0
# 0.730427544602
# sample number 249
# number of input states with zero probability 0
# 0.808235301327
# sample number 250
# number of input states with zero probability 0
# 0.8363487191
# sample number 251
# number of input states with zero probability 0
# 0.865356072269
# sample number 252
# number of input states with zero probability 0
# 0.751403414434
# sample number 253
# number of input states with zero probability 0
# 0.722594843871
# sample number 254
# number of input states with zero probability 0
# 1.13963362202
# sample number 255
# number of input states with zero probability 0
# 0.777222348994
# sample number 256
# number of input states with zero probability 0
# 0.73864059353
# sample number 257
# number of input states with zero probability 0
# 0.757920900479
# sample number 258
# number of input states with zero probability 0
# 0.679970545035
# sample number 259
# number of input states with zero probability 0
# 0.970222010288
# sample number 260
# number of input states with zero probability 0
# 0.682003356358
# sample number 261
# number of input states with zero probability 0
# 0.743625314581
# sample number 262
# number of input states with zero probability 0
# 0.710897638534
# sample number 263
# number of input states with zero probability 0
# 0.923062139463
# sample number 264
# number of input states with zero probability 0
# 0.794518134999
# sample number 265
# number of input states with zero probability 0
# 0.747789381953
# sample number 266
# number of input states with zero probability 0
# 0.739456339166
# sample number 267
# number of input states with zero probability 0
# 0.803038125691
# sample number 268
# number of input states with zero probability 0
# 0.913456491869
# sample number 269
# number of input states with zero probability 0
# 0.782795659513
# sample number 270
# number of input states with zero probability 0
# 1.06674755145
# sample number 271
# number of input states with zero probability 0
# 0.679193404938
# sample number 272
# number of input states with zero probability 0
# 0.763235024711
# sample number 273
# number of input states with zero probability 0
# 0.857227969525
# sample number 274
# number of input states with zero probability 0
# 0.855186652521
# sample number 275
# number of input states with zero probability 0
# 0.903861018233
# sample number 276
# number of input states with zero probability 0
# 0.742746357628
# sample number 277
# number of input states with zero probability 0
# 0.871991074144
# sample number 278
# number of input states with zero probability 0
# 0.772176154702
# sample number 279
# number of input states with zero probability 0
# 0.802744839139
# sample number 280
# number of input states with zero probability 0
# 1.01725474878
# sample number 281
# number of input states with zero probability 0
# 0.797100047608
# sample number 282
# number of input states with zero probability 0
# 0.798397451179
# sample number 283
# number of input states with zero probability 0
# 0.772447897658
# sample number 284
# number of input states with zero probability 0
# 0.688499757655
# sample number 285
# number of input states with zero probability 0
# 1.18076561325
# sample number 286
# number of input states with zero probability 0
# 0.862315333953
# sample number 287
# number of input states with zero probability 0
# 0.814775112373
# sample number 288
# number of input states with zero probability 0
# 0.734873726543
# sample number 289
# number of input states with zero probability 0
# 0.737849392275
# sample number 290
# number of input states with zero probability 0
# 0.862783254311
# sample number 291
# number of input states with zero probability 0
# 0.969296053231
# sample number 292
# number of input states with zero probability 0
# 0.775072105826
# sample number 293
# number of input states with zero probability 0
# 0.975638349674
# sample number 294
# number of input states with zero probability 0
# 0.615451621461
# sample number 295
# number of input states with zero probability 0
# 0.752410315239
# sample number 296
# number of input states with zero probability 0
# 1.09068162596
# sample number 297
# number of input states with zero probability 0
# 0.736108864938
# sample number 298
# number of input states with zero probability 0
# 0.695017799884
# sample number 299
# number of input states with zero probability 0
# 0.823322802453
# number of variables 4
# sample number 200
# number of input states with zero probability 0
# 0.650542357913
# sample number 201
# number of input states with zero probability 0
# 0.542770323847
# sample number 202
# number of input states with zero probability 0
# 0.476686361805
# sample number 203
# number of input states with zero probability 0
# 0.561039098287
# sample number 204
# number of input states with zero probability 0
# 0.580644755292
# sample number 205
# number of input states with zero probability 0
# 0.611418896487
# sample number 206
# number of input states with zero probability 0
# 0.600352609436
# sample number 207
# number of input states with zero probability 0
# 0.644524251843
# sample number 208
# number of input states with zero probability 0
# 0.511286491301
# sample number 209
# number of input states with zero probability 0
# 0.560866615413
# sample number 210
# number of input states with zero probability 0
# 0.538348962113
# sample number 211
# number of input states with zero probability 0
# 0.557773746722
# sample number 212
# number of input states with zero probability 0
# 0.552280933696
# sample number 213
# number of input states with zero probability 0
# 0.551870309714
# sample number 214
# number of input states with zero probability 0
# 0.580695435449
# sample number 215
# number of input states with zero probability 0
# 0.498355083592
# sample number 216
# number of input states with zero probability 0
# 0.672011406611
# sample number 217
# number of input states with zero probability 0
# 0.539753376926
# sample number 218
# number of input states with zero probability 0
# 0.642848048861
# sample number 219
# number of input states with zero probability 0
# 0.52359464085
# sample number 220
# number of input states with zero probability 0
# 0.559563083606
# sample number 221
# number of input states with zero probability 0
# 0.463328667835
# sample number 222
# number of input states with zero probability 0
# 0.515755954644
# sample number 223
# number of input states with zero probability 0
# 0.586075788614
# sample number 224
# number of input states with zero probability 0
# 0.572738349
# sample number 225
# number of input states with zero probability 0
# 0.505986462862
# sample number 226
# number of input states with zero probability 0
# 0.511608389583
# sample number 227
# number of input states with zero probability 0
# 0.591757018634
# sample number 228
# number of input states with zero probability 0
# 0.61513102437
# sample number 229
# number of input states with zero probability 0
# 0.541168898613
# sample number 230
# number of input states with zero probability 0
# 0.586643672915
# sample number 231
# number of input states with zero probability 0
# 0.677690020829
# sample number 232
# number of input states with zero probability 0
# 0.635191930689
# sample number 233
# number of input states with zero probability 0
# 0.643787887247
# sample number 234
# number of input states with zero probability 0
# 0.565289527647
# sample number 235
# number of input states with zero probability 0
# 0.559546583956
# sample number 236
# number of input states with zero probability 0
# 0.477616675185
# sample number 237
# number of input states with zero probability 0
# 0.653921796585
# sample number 238
# number of input states with zero probability 0
# 0.609839653584
# sample number 239
# number of input states with zero probability 0
# 0.54108065853
# sample number 240
# number of input states with zero probability 0
# 0.515556824247
# sample number 241
# number of input states with zero probability 0
# 0.43812903059
# sample number 242
# number of input states with zero probability 0
# 0.537406382997
# sample number 243
# number of input states with zero probability 0
# 0.529292381355
# sample number 244
# number of input states with zero probability 0
# 0.524221798503
# sample number 245
# number of input states with zero probability 0
# 0.522926153653
# sample number 246
# number of input states with zero probability 0
# 0.476205207319
# sample number 247
# number of input states with zero probability 0
# 0.584741689559
# sample number 248
# number of input states with zero probability 0
# 0.497191159961
# sample number 249
# number of input states with zero probability 0
# 0.564222686299
# sample number 250
# number of input states with zero probability 0
# 0.614849526176
# sample number 251
# number of input states with zero probability 0
# 0.576890831255
# sample number 252
# number of input states with zero probability 0
# 0.537296785624
# sample number 253
# number of input states with zero probability 0
# 0.549375630814
# sample number 254
# number of input states with zero probability 0
# 0.570859578795
# sample number 255
# number of input states with zero probability 0
# 0.598881150633
# sample number 256
# number of input states with zero probability 0
# 0.589227969926
# sample number 257
# number of input states with zero probability 0
# 0.579814347618
# sample number 258
# number of input states with zero probability 0
# 0.549504179219
# sample number 259
# number of input states with zero probability 0
# 0.586421557965
# sample number 260
# number of input states with zero probability 0
# 0.513756799546
# sample number 261
# number of input states with zero probability 0
# 0.477492532625
# sample number 262
# number of input states with zero probability 0
# 0.640068418088
# sample number 263
# number of input states with zero probability 0
# 0.437575244361
# sample number 264
# number of input states with zero probability 0
# 0.501185427563
# sample number 265
# number of input states with zero probability 0
# 0.541212818683
# sample number 266
# number of input states with zero probability 0
# 0.594673529901
# sample number 267
# number of input states with zero probability 0
# 0.547364564032
# sample number 268
# number of input states with zero probability 0
# 0.597698607057
# sample number 269
# number of input states with zero probability 0
# 0.589861645182
# sample number 270
# number of input states with zero probability 0
# 0.503085826191
# sample number 271
# number of input states with zero probability 0
# 0.707890297156
# sample number 272
# number of input states with zero probability 0
# 0.585346425878
# sample number 273
# number of input states with zero probability 0
# 0.494797096685
# sample number 274
# number of input states with zero probability 0
# 0.611679889757
# sample number 275
# number of input states with zero probability 0
# 0.532419405214
# sample number 276
# number of input states with zero probability 0
# 0.529359356861
# sample number 277
# number of input states with zero probability 0
# 0.603545126717
# sample number 278
# number of input states with zero probability 0
# 0.623198254614
# sample number 279
# number of input states with zero probability 0
# 0.543183854473
# sample number 280
# number of input states with zero probability 0
# 0.51945278295
# sample number 281
# number of input states with zero probability 0
# 0.646285446925
# sample number 282
# number of input states with zero probability 0
# 0.577522147843
# sample number 283
# number of input states with zero probability 0
# 0.652448563551
# sample number 284
# number of input states with zero probability 0
# 0.552908110278
# sample number 285
# number of input states with zero probability 0
# 0.626964823314
# sample number 286
# number of input states with zero probability 0
# 0.578311215192
# sample number 287
# number of input states with zero probability 0
# 0.675794308863
# sample number 288
# number of input states with zero probability 0
# 0.542985017172
# sample number 289
# number of input states with zero probability 0
# 0.546448260593
# sample number 290
# number of input states with zero probability 0
# 0.542119024098
# sample number 291
# number of input states with zero probability 0
# 0.571949242881
# sample number 292
# number of input states with zero probability 0
# 0.480095430958
# sample number 293
# number of input states with zero probability 0
# 0.505965761112
# sample number 294
# number of input states with zero probability 0
# 0.540345126233
# sample number 295
# number of input states with zero probability 0
# 0.467276520773
# sample number 296
# number of input states with zero probability 0
# 0.535719516789
# sample number 297
# number of input states with zero probability 0
# 0.582106413512
# sample number 298
# number of input states with zero probability 0
# 0.548377325525
# sample number 299
# number of input states with zero probability 0
# 0.60192957779
# number of variables 5
# sample number 200
# number of input states with zero probability 0
# 0.449805063376
# sample number 201
# number of input states with zero probability 0
# 0.436677946828
# sample number 202
# number of input states with zero probability 0
# 0.367141008905
# sample number 203
# number of input states with zero probability 0
# 0.412538200495
# sample number 204
# number of input states with zero probability 0
# 0.387343375209
# sample number 205
# number of input states with zero probability 0
# 0.426267564584
# sample number 206
# number of input states with zero probability 0
# 0.39486006459
# sample number 207
# number of input states with zero probability 0
# 0.397595697047
# sample number 208
# number of input states with zero probability 0
# 0.450200684484
# sample number 209
# number of input states with zero probability 0
# 0.456588260402
# sample number 210
# number of input states with zero probability 0
# 0.436005129746
# sample number 211
# number of input states with zero probability 0
# 0.39320040101
# sample number 212
# number of input states with zero probability 0
# 0.430933619008
# sample number 213
# number of input states with zero probability 0
# 0.41061771904
# sample number 214
# number of input states with zero probability 0
# 0.405261537196
# sample number 215
# number of input states with zero probability 0
# 0.466736017864
# sample number 216
# number of input states with zero probability 0
# 0.407661958252
# sample number 217
# number of input states with zero probability 0
# 0.429819587317
# sample number 218
# number of input states with zero probability 0
# 0.401133132219
# sample number 219
# number of input states with zero probability 0
# 0.397259774161
# sample number 220
# number of input states with zero probability 0
# 0.393746821392
# sample number 221
# number of input states with zero probability 0
# 0.405761973858
# sample number 222
# number of input states with zero probability 0
# 0.42125254598
# sample number 223
# number of input states with zero probability 0
# 0.38491095866
# sample number 224
# number of input states with zero probability 0
# 0.415889396888
# sample number 225
# number of input states with zero probability 0
# 0.431873578693
# sample number 226
# number of input states with zero probability 0
# 0.360294302324
# sample number 227
# number of input states with zero probability 0
# 0.395950352842
# sample number 228
# number of input states with zero probability 0
# 0.401400368643
# sample number 229
# number of input states with zero probability 0
# 0.388069738336
# sample number 230
# number of input states with zero probability 0
# 0.420172335456
# sample number 231
# number of input states with zero probability 0
# 0.433677422273
# sample number 232
# number of input states with zero probability 0
# 0.419800435795
# sample number 233
# number of input states with zero probability 0
# 0.416721859754
# sample number 234
# number of input states with zero probability 0
# 0.461496982091
# sample number 235
# number of input states with zero probability 0
# 0.453751985068
# sample number 236
# number of input states with zero probability 0
# 0.444323923676
# sample number 237
# number of input states with zero probability 0
# 0.376855158124
# sample number 238
# number of input states with zero probability 0
# 0.425960997719
# sample number 239
# number of input states with zero probability 0
# 0.363201888903
# sample number 240
# number of input states with zero probability 0
# 0.427114320032
# sample number 241
# number of input states with zero probability 0
# 0.417469359793
# sample number 242
# number of input states with zero probability 0
# 0.389981571803
# sample number 243
# number of input states with zero probability 0
# 0.358819183835
# sample number 244
# number of input states with zero probability 0
# 0.423391187213
# sample number 245
# number of input states with zero probability 0
# 0.394715537428
# sample number 246
# number of input states with zero probability 0
# 0.445465265912
# sample number 247
# number of input states with zero probability 0
# 0.390391544757
# sample number 248
# number of input states with zero probability 0
# 0.433148589211
# sample number 249
# number of input states with zero probability 0
# 0.442921823086
# sample number 250
# number of input states with zero probability 0
# 0.445236414001
# sample number 251
# number of input states with zero probability 0
# 0.406076131955
# sample number 252
# number of input states with zero probability 0
# 0.383496905064
# sample number 253
# number of input states with zero probability 0
# 0.427362237114
# sample number 254
# number of input states with zero probability 0
# 0.445094873931
# sample number 255
# number of input states with zero probability 0
# 0.426138945969
# sample number 256
# number of input states with zero probability 0
# 0.391219399818
# sample number 257
# number of input states with zero probability 0
# 0.410313038503
# sample number 258
# number of input states with zero probability 0
# 0.404222665668
# sample number 259
# number of input states with zero probability 0
# 0.455855575043
# sample number 260
# number of input states with zero probability 0
# 0.411151510997
# sample number 261
# number of input states with zero probability 0
# 0.402769635301
# sample number 262
# number of input states with zero probability 0
# 0.424972718242
# sample number 263
# number of input states with zero probability 0
# 0.426220280089
# sample number 264
# number of input states with zero probability 0
# 0.474877787225
# sample number 265
# number of input states with zero probability 0
# 0.382445520011
# sample number 266
# number of input states with zero probability 0
# 0.450587195603
# sample number 267
# number of input states with zero probability 0
# 0.40003790249
# sample number 268
# number of input states with zero probability 0
# 0.371837809878
# sample number 269
# number of input states with zero probability 0
# 0.399393068116
# sample number 270
# number of input states with zero probability 0
# 0.344138565218
# sample number 271
# number of input states with zero probability 0
# 0.383027486818
# sample number 272
# number of input states with zero probability 0
# 0.456416962961
# sample number 273
# number of input states with zero probability 0
# 0.429463370803
# sample number 274
# number of input states with zero probability 0
# 0.448733308568
# sample number 275
# number of input states with zero probability 0
# 0.481621605748
# sample number 276
# number of input states with zero probability 0
# 0.396469381356
# sample number 277
# number of input states with zero probability 0
# 0.49340180693
# sample number 278
# number of input states with zero probability 0
# 0.420459412202
# sample number 279
# number of input states with zero probability 0
# 0.377469879426
# sample number 280
# number of input states with zero probability 0
# 0.385676962485
# sample number 281
# number of input states with zero probability 0
# 0.451745596691
# sample number 282
# number of input states with zero probability 0
# 0.423127863291
# sample number 283
# number of input states with zero probability 0
# 0.35789712071
# sample number 284
# number of input states with zero probability 0
# 0.417449325021
# sample number 285
# number of input states with zero probability 0
# 0.429933611327
# sample number 286
# number of input states with zero probability 0
# 0.437055811523
# sample number 287
# number of input states with zero probability 0
# 0.354234180383
# sample number 288
# number of input states with zero probability 0
# 0.377270977436
# sample number 289
# number of input states with zero probability 0
# 0.409598660277
# sample number 290
# number of input states with zero probability 0
# 0.410842077987
# sample number 291
# number of input states with zero probability 0
# 0.39819987747
# sample number 292
# number of input states with zero probability 0
# 0.33903157205
# sample number 293
# number of input states with zero probability 0
# 0.490877359298
# sample number 294
# number of input states with zero probability 0
# 0.474790342613
# sample number 295
# number of input states with zero probability 0
# 0.407399443978
# sample number 296
# number of input states with zero probability 0
# 0.402932102445
# sample number 297
# number of input states with zero probability 0
# 0.370607907787
# sample number 298
# number of input states with zero probability 0
# 0.505566703068
# sample number 299
# number of input states with zero probability 0
# 0.432382112888
# number of variables 6
# sample number 200
# number of input states with zero probability 0
# 0.387015627966
# sample number 201
# number of input states with zero probability 0
# 0.372858759469
# sample number 202
# number of input states with zero probability 0
# 0.346386499739
# sample number 203
# number of input states with zero probability 0
# 0.36543635062
# sample number 204
# number of input states with zero probability 0
# 0.364560674842
# sample number 205
# number of input states with zero probability 0
# 0.378867843557
# sample number 206
# number of input states with zero probability 0
# 0.341182825835
# sample number 207
# number of input states with zero probability 0
# 0.411905281092
# sample number 208
# number of input states with zero probability 0
# 0.379598451366
# sample number 209
# number of input states with zero probability 0
# 0.365851966691
# sample number 210
# number of input states with zero probability 0
# 0.343561401825
# sample number 211
# number of input states with zero probability 0
# 0.341465796231
# sample number 212
# number of input states with zero probability 0
# 0.375146365305
# sample number 213
# number of input states with zero probability 0
# 0.387165339749
# sample number 214
# number of input states with zero probability 0
# 0.359164246783
# sample number 215
# number of input states with zero probability 0
# 0.376623530832
# sample number 216
# number of input states with zero probability 0
# 0.36094980751
# sample number 217
# number of input states with zero probability 0
# 0.375478656134
# sample number 218
# number of input states with zero probability 0
# 0.323332903097
# sample number 219
# number of input states with zero probability 0
# 0.328945900501
# sample number 220
# number of input states with zero probability 0
# 0.339060801131
# sample number 221
# number of input states with zero probability 0
# 0.349034905611
# sample number 222
# number of input states with zero probability 0
# 0.350037294495
# sample number 223
# number of input states with zero probability 0
# 0.345190233554
# sample number 224
# number of input states with zero probability 0
# 0.360503105731
# sample number 225
# number of input states with zero probability 0
# 0.378743044977
# sample number 226
# number of input states with zero probability 0
# 0.376020447347
# sample number 227
# number of input states with zero probability 0
# 0.413076910462
# sample number 228
# number of input states with zero probability 0
# 0.38538073436
# sample number 229
# number of input states with zero probability 0
# 0.354146980253
# sample number 230
# number of input states with zero probability 0
# 0.372734050687
# sample number 231
# number of input states with zero probability 0
# 0.387757753436
# sample number 232
# number of input states with zero probability 0
# 0.361314952724
# sample number 233
# number of input states with zero probability 0
# 0.332634953826
# sample number 234
# number of input states with zero probability 0
# 0.354373938351
# sample number 235
# number of input states with zero probability 0
# 0.409616285756
# sample number 236
# number of input states with zero probability 0
# 0.359011788808
# sample number 237
# number of input states with zero probability 0
# 0.359618804821
# sample number 238
# number of input states with zero probability 0
# 0.357530111653
# sample number 239
# number of input states with zero probability 0
# 0.377071684278
# sample number 240
# number of input states with zero probability 0
# 0.37448449708
# sample number 241
# number of input states with zero probability 0
# 0.373810200125
# sample number 242
# number of input states with zero probability 0
# 0.337193424425
# sample number 243
# number of input states with zero probability 0
# 0.349641681358
# sample number 244
# number of input states with zero probability 0
# 0.421342357189
# sample number 245
# number of input states with zero probability 0
# 0.389768426754
# sample number 246
# number of input states with zero probability 0
# 0.375912191475
# sample number 247
# number of input states with zero probability 0
# 0.419287914475
# sample number 248
# number of input states with zero probability 0
# 0.359229641033
# sample number 249
# number of input states with zero probability 0
# 0.337815837133
# sample number 250
# number of input states with zero probability 0
# 0.342270668243
# sample number 251
# number of input states with zero probability 0
# 0.359901559341
# sample number 252
# number of input states with zero probability 0
# 0.388619720622
# sample number 253
# number of input states with zero probability 0
# 0.361409865281
# sample number 254
# number of input states with zero probability 0
# 0.355783648784
# sample number 255
# number of input states with zero probability 0
# 0.375780465458
# sample number 256
# number of input states with zero probability 0
# 0.340284551861
# sample number 257
# number of input states with zero probability 0
# 0.426419662708
# sample number 258
# number of input states with zero probability 0
# 0.3536295115
# sample number 259
# number of input states with zero probability 0
# 0.400961656349
# sample number 260
# number of input states with zero probability 0
# 0.365661150972
# sample number 261
# number of input states with zero probability 0
# 0.376998567154
# sample number 262
# number of input states with zero probability 0
# 0.371096238244
# sample number 263
# number of input states with zero probability 0
# 0.375745982306
# sample number 264
# number of input states with zero probability 0
# 0.356839015919
# sample number 265
# number of input states with zero probability 0
# 0.374618514766
# sample number 266
# number of input states with zero probability 0
# 0.344586189771
# sample number 267
# number of input states with zero probability 0
# 0.338895559406
# sample number 268
# number of input states with zero probability 0
# 0.37384931137
# sample number 269
# number of input states with zero probability 0
# 0.390130186135
# sample number 270
# number of input states with zero probability 0
# 0.392752773716
# sample number 271
# number of input states with zero probability 0
# 0.352827612707
# sample number 272
# number of input states with zero probability 0
# 0.399058224057
# sample number 273
# number of input states with zero probability 0
# 0.354438460537
# sample number 274
# number of input states with zero probability 0
# 0.356166773541
# sample number 275
# number of input states with zero probability 0
# 0.388186502136
# sample number 276
# number of input states with zero probability 0
# 0.395583771529
# sample number 277
# number of input states with zero probability 0
# 0.316838147383
# sample number 278
# number of input states with zero probability 0
# 0.386884197267
# sample number 279
# number of input states with zero probability 0
# 0.363018502147
# sample number 280
# number of input states with zero probability 0
# 0.388011798628
# sample number 281
# number of input states with zero probability 0
# 0.324210049509
# sample number 282
# number of input states with zero probability 0
# 0.311267340114
# sample number 283
# number of input states with zero probability 0
# 0.359791661612
# sample number 284
# number of input states with zero probability 0
# 0.340000159225
# sample number 285
# number of input states with zero probability 0
# 0.372661835477
# sample number 286
# number of input states with zero probability 0
# 0.328708870989
# sample number 287
# number of input states with zero probability 0
# 0.360702259437
# sample number 288
# number of input states with zero probability 0
# 0.353956828544
# sample number 289
# number of input states with zero probability 0
# 0.328608445235
# sample number 290
# number of input states with zero probability 0
# 0.3622913912
# sample number 291
# number of input states with zero probability 0
# 0.391950148377
# sample number 292
# number of input states with zero probability 0
# 0.375011357932
# sample number 293
# number of input states with zero probability 0
# 0.398239403052
# sample number 294
# number of input states with zero probability 0
# 0.374882121309
# sample number 295
# number of input states with zero probability 0
# 0.365164677434
# sample number 296
# number of input states with zero probability 0
# 0.373589515809
# sample number 297
# number of input states with zero probability 0
# 0.353823169496
# sample number 298
# number of input states with zero probability 0
# 0.367159616245
# sample number 299
# number of input states with zero probability 0
# 0.35892330931
# number of variables 7
# sample number 200
# number of input states with zero probability 0
# 0.371481954545
# sample number 201
# number of input states with zero probability 0
# 0.374767893305
# sample number 202
# number of input states with zero probability 0
# 0.41002510474
# sample number 203
# number of input states with zero probability 0
# 0.361365459227
# sample number 204
# number of input states with zero probability 0
# 0.378402381898
# sample number 205
# number of input states with zero probability 0
# 0.378724821259
# sample number 206
# number of input states with zero probability 0
# 0.326916212725
# sample number 207
# number of input states with zero probability 0
# 0.378000738144
# sample number 208
# number of input states with zero probability 0
# 0.380563393069
# sample number 209
# number of input states with zero probability 0
# 0.367960558244
# sample number 210
# number of input states with zero probability 0
# 0.405942084274
# sample number 211
# number of input states with zero probability 0
# 0.377644929465
# sample number 212
# number of input states with zero probability 0
# 0.390649891876
# sample number 213
# number of input states with zero probability 0
# 0.38511246201
# sample number 214
# number of input states with zero probability 0
# 0.365990707514
# sample number 215
# number of input states with zero probability 0
# 0.369444516551
# sample number 216
# number of input states with zero probability 0
# 0.367070478099
# sample number 217
# number of input states with zero probability 0
# 0.385398850909
# sample number 218
# number of input states with zero probability 0
# 0.391083582881
# sample number 219
# number of input states with zero probability 0
# 0.403815567498
# sample number 220
# number of input states with zero probability 0
# 0.397906944255
# sample number 221
# number of input states with zero probability 0
# 0.389441448057
# sample number 222
# number of input states with zero probability 0
# 0.352201805787
# sample number 223
# number of input states with zero probability 0
# 0.365243176203
# sample number 224
# number of input states with zero probability 0
# 0.371430886656
# sample number 225
# number of input states with zero probability 0
# 0.37763077005
# sample number 226
# number of input states with zero probability 0
# 0.364073185411
# sample number 227
# number of input states with zero probability 0
# 0.384891177995
# sample number 228
# number of input states with zero probability 0
# 0.365413696029
# sample number 229
# number of input states with zero probability 0
# 0.364879634117
# sample number 230
# number of input states with zero probability 0
# 0.405705086689
# sample number 231
# number of input states with zero probability 0
# 0.384476671009
# sample number 232
# number of input states with zero probability 0
# 0.395538794297
# sample number 233
# number of input states with zero probability 0
# 0.366093757524
# sample number 234
# number of input states with zero probability 0
# 0.341350652827
# sample number 235
# number of input states with zero probability 0
# 0.38928896512
# sample number 236
# number of input states with zero probability 0
# 0.404531757974
# sample number 237
# number of input states with zero probability 0
# 0.371476826358
# sample number 238
# number of input states with zero probability 0
# 0.367566792644
# sample number 239
# number of input states with zero probability 0
# 0.34655198552
# sample number 240
# number of input states with zero probability 0
# 0.381478425357
# sample number 241
# number of input states with zero probability 0
# 0.361162556768
# sample number 242
# number of input states with zero probability 0
# 0.384949499278
# sample number 243
# number of input states with zero probability 0
# 0.382205121028
# sample number 244
# number of input states with zero probability 0
# 0.343950786764
# sample number 245
# number of input states with zero probability 0
# 0.350568880066
# sample number 246
# number of input states with zero probability 0
# 0.363322510189
# sample number 247
# number of input states with zero probability 0
# 0.35625833217
# sample number 248
# number of input states with zero probability 0
# 0.400205385982
# sample number 249
# number of input states with zero probability 0
# 0.405050922251
# sample number 250
# number of input states with zero probability 0
# 0.357049109111
# sample number 251
# number of input states with zero probability 0
# 0.351853269475
# sample number 252
# number of input states with zero probability 0
# 0.368589660413
# sample number 253
# number of input states with zero probability 0
# 0.396801140471
# sample number 254
# number of input states with zero probability 0
# 0.354090941309
# sample number 255
# number of input states with zero probability 0
# 0.373833904281
# sample number 256
# number of input states with zero probability 0
# 0.382833543359
# sample number 257
# number of input states with zero probability 0
# 0.398341790545
# sample number 258
# number of input states with zero probability 0
# 0.375102896303
# sample number 259
# number of input states with zero probability 0
# 0.368607563671
# sample number 260
# number of input states with zero probability 0
# 0.401566893944
# sample number 261
# number of input states with zero probability 0
# 0.373255628233
# sample number 262
# number of input states with zero probability 0
# 0.349748182526
# sample number 263
# number of input states with zero probability 0
# 0.372124314994
# sample number 264
# number of input states with zero probability 0
# 0.381855448547
# sample number 265
# number of input states with zero probability 0
# 0.384802288882
# sample number 266
# number of input states with zero probability 0
# 0.365964081838
# sample number 267
# number of input states with zero probability 0
# 0.366787319058
# sample number 268
# number of input states with zero probability 0
# 0.347239318396
# sample number 269
# number of input states with zero probability 0
# 0.413475439975
# sample number 270
# number of input states with zero probability 0
# 0.360921526969
# sample number 271
# number of input states with zero probability 0
# 0.380506338445
# sample number 272
# number of input states with zero probability 0
# 0.391436100753
# sample number 273
# number of input states with zero probability 0
# 0.386096406982
# sample number 274
# number of input states with zero probability 0
# 0.387334453024
# sample number 275
# number of input states with zero probability 0
# 0.346879931872
# sample number 276
# number of input states with zero probability 0
# 0.37135679232
# sample number 277
# number of input states with zero probability 0
# 0.382068653754
# sample number 278
# number of input states with zero probability 0
# 0.402393780029
# sample number 279
# number of input states with zero probability 0
# 0.397341339279
# sample number 280
# number of input states with zero probability 0
# 0.38450466363
# sample number 281
# number of input states with zero probability 0
# 0.394015103818
# sample number 282
# number of input states with zero probability 0
# 0.39839735995
# sample number 283
# number of input states with zero probability 0
# 0.394910361784
# sample number 284
# number of input states with zero probability 0
# 0.388590300429
# sample number 285
# number of input states with zero probability 0
# 0.385609390723
# sample number 286
# number of input states with zero probability 0
# 0.365880072502
# sample number 287
# number of input states with zero probability 0
# 0.387885198476
# sample number 288
# number of input states with zero probability 0
# 0.395625011444
# sample number 289
# number of input states with zero probability 0
# 0.390621737696
# sample number 290
# number of input states with zero probability 0
# 0.373612649309
# sample number 291
# number of input states with zero probability 0
# 0.382325369212
# sample number 292
# number of input states with zero probability 0
# 0.358743308577
# sample number 293
# number of input states with zero probability 0
# 0.361038733919
# sample number 294
# number of input states with zero probability 0
# 0.378140393322
# sample number 295
# number of input states with zero probability 0
# 0.372403783139
# sample number 296
# number of input states with zero probability 0
# 0.389144088158
# sample number 297
# number of input states with zero probability 0
# 0.358413810323
# sample number 298
# number of input states with zero probability 0
# 0.388769836461
# sample number 299
# number of input states with zero probability 0
# 0.391673092957
