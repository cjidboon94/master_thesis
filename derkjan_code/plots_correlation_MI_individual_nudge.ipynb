# %%
import json
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
DATA_PATH = "data_experiments/"
file_names = [
    "correlation_MI_individual_nudge_impact_2var_5states_l1norm_ex2.json",
]

# %%
with open(DATA_PATH+file_names[0], 'r') as f:
    impact_nudges_and_mi = json.load(f)
    
impact_nudges = [item[0] for item in impact_nudges_and_mi] 
mutual_information_sizes = [item[1] for item in impact_nudges_and_mi]
plt.plot(mutual_information_sizes, impact_nudges, 'o')
plt.show()
print(scipy.stats.linregress(impact_nudges, mutual_information_sizes))
# Out:
# LinregressResult(slope=38.71761518897231, intercept=-0.18041809959148472, rvalue=0.53585289346086384, pvalue=1.0707395808876519e-23, stderr=3.5339265661822634)
