# %% [markdown]
# ### Introduction
#
# This notebook aims to find the impact of random nudges

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json

import numpy as np
from scipy import stats

import probability_distributions
import maximum_nudges
import evolutionary_algorithms as ea
import maximum_synergistic_nudge_evolutionary as synergistic_nudge_ev
import maximum_nudges_evolutionary as ev_max_nudges
import nudge
import nudge_non_causal
import get_data

# %% [markdown]
# ### Notebook level constants

# %%
NUDGE_SIZE = 0.01
PATH_TO_DISTRIBUTIONS = "/home/joboti/azumi_derkjan/master_thesis/code/"

# %%
def calculate_amount_and_size_nudges(total_nudge_size, number_of_states, threshold=10):
    """
    Calculate the nudge size and the number of nudges that need to be performed 
    to nudge a variable with the total nudge size. Assuming the distribution is
    not too peaked, in other words, not too many states should have a probability
    that is 10 times smaller than normal.
    
    Parameters:
    ----------
    total_nudge_size: a number
        How much the variable need to be nudged
    number_of_states: a number
        The total number of states of the joint distribution
    threshold: a float 
        Indicating how much smaller than uniform the value of the number
        at the 95-99 percentile of points is. Defaults to 10 
        
    Returns: local_nudge, number_of_nudges
    -------
    local_nudge: a number 
        The size of the local nudge to be performed on the joint distribution
    number_of_nudges: integer
        How often the nudge need to be performed
    
    """
    assumed_min_size = 1.0/threshold
    max_local_nudge = min(total_nudge_size, 0.1/number_of_states)
    number_of_nudges = int(np.ceil(total_nudge_size/max_local_nudge))
    local_nudge = total_nudge_size/float(number_of_nudges) 
    return local_nudge, number_of_nudges

# %% [markdown]
# ### Find the random impact of a nudge given the nudge type, the input and conditional output, and nudge size

# %%
def get_random_nudge_impacts(input_dists, cond_output_dists, nudge_size, nudge_type, 
                             number_of_samples, backup_filename, parameters):
    """
    Find the maximum impact of the nudges
    
    Parameters:
    ----------
    input_dists: list of nd-arrays representing probability distributions
    cond_output_dists: list of nd-arrays 
        Representing output distributions (the last axis) conditioned on the input 
        distributions
    nudge_size: positive float
    nudge_type: string
        One of the following: {"individual", "focused", "local", "synergistic", "global"}
    number_of_samples: int
    filename_to_save: string, 
        Should be a valid path
    parameters: a dict,
        The parameters used to find the maximum nudge
    
    """
    dist_impacts = []
    missed_weight_dist = 0
    for input_dist, cond_output in zip(input_dists, cond_output_dists):
        print("count {}".format(len(dist_impacts)))
        impacts = []
        missed_weights = []
        for _ in range(number_of_samples):
            if nudge_type == "individual":
                new_dist = nudge_non_causal.nudge_individual_without_conditional(input_dist, nudge_size)
            elif nudge_type == "focused":
                local_nudge_size, number_of_nudges = calculate_amount_and_size_nudges(
                    nudge_size/2, input_dist.flatten().shape[0], threshold=parameters["threshold"]
                )
                num_vars = len(input_dist.shape)
                new_dist = nudge.nudge_distribution_local_non_causal(
                    input_dist, num_vars-1, local_nudge_size, number_of_nudges
                )
            elif nudge_type == "local":
                new_dist = nudge_non_causal.nudge_local(
                    input_dist, nudged_vars=parameters["nudged_vars"], nudge_size=nudge_size,
                    without_conditional=True
                )
            elif nudge_type == "synergistic":
                new_dist = np.copy(input_dist)
                for _ in range(parameters["max_number_of_mutations"]):
                    nudge_non_causal.synergistic_mutate(
                        new_dist, parameters["mutation_size"]
                    )
                    new_nudge_size = np.sum(abs(new_dist-input_dist))
                    adjustment_factor = nudge_size/new_nudge_size
                    if adjustment_factor <= 1:
                        new_dist = input_dist + (new_dist-input_dist)*adjustment_factor
                        break

                if adjustment_factor > 1:
                    print("WARNING: nudge size only {} percent of intended nudge size".format(adjustment_factor))
            elif nudge_type == "global":
                new_dist = nudge_non_causal.nudge_global(input_dist, nudge_size, without_conditional=True)
            else:
                raise ValueError("provide a valid nudge type")

            l1_norm_to_old_distribution = np.sum(np.absolute(input_dist-new_dist))
            impacts.append(nudge_non_causal.find_nudge_impact(input_dist, new_dist, cond_output))
            missed_weights.append(abs(l1_norm_to_old_distribution-NUDGE_SIZE))

        print("the nudge impact {}".format(np.mean(impacts)))
        if np.mean(missed_weights) > nudge_size/100:
            print("WARNING missed weight equals {} percentage of nudge_size".format(
                (np.mean(missed_weights)/nudge_size) * 100
            ))
        
        missed_weight_dist += np.mean(missed_weights)
        dist_impacts.append(np.mean(impacts))
        with open(backup_filename, 'w') as f:
            json.dump(impacts, f, indent=4)
        
    print("total missed weight {}".format(missed_weight_dist))
    return dist_impacts, missed_weight_dist

# %% [markdown]
# ### Generate the data and run the experiments

# %% [markdown]
# #### First for system distributions with limited entropy

# %%
PERCENTAGE_MAX_ENTROPY_SIZE = 75
NUMBER_OF_VARS = 7
NUMBER_OF_STATES = 3
FILENAME_FORMAT_INPUT = "input_dist_exact_{}.npy"
FILENAME_FORMAT_OUTPUT = "cond_output_dist_exact_{}.npy"
DIST_START = 200
DIST_END = 300
NUDGE_TYPE = "global"
NUMBER_OF_SAMPLES = 100

MAX_NUMBER_OF_MUTATIONS = 27
MUTATION_SIZE = NUDGE_SIZE/9
THRESHOLD = 50

distribution_numbers = list(range(DIST_START, DIST_END, 1))
if NUDGE_TYPE == "global" or NUDGE_TYPE =="individual": 
    parameters = None
elif NUDGE_TYPE== "focused":
    parameters = {
        "threshold": THRESHOLD
    }
elif NUDGE_TYPE == "local":
    parameters = {
        "nudged_vars": list(range(NUMBER_OF_VARS-1))
    }
elif NUDGE_TYPE == "synergistic":
    parameters = {
        "max_number_of_mutations": MAX_NUMBER_OF_MUTATIONS,
        "mutation_size": MUTATION_SIZE
    }

backup_filename = ("data_experiments/" + 
    "backup_random_impacts_validate_{}var_{}states_{}entropy_{}_nudge_dists{}-{}.json".format(
        NUMBER_OF_VARS, NUMBER_OF_STATES, PERCENTAGE_MAX_ENTROPY_SIZE, NUDGE_TYPE, DIST_START, DIST_END 
    )
)
path_to_limited_entropy_system_dists = (
    PATH_TO_DISTRIBUTIONS + "system_distributions/" 
    + "limited_entropy/"
)

input_dists = get_data.get_system_distributions_limited_entropy(
    path_to_limited_entropy_system_dists, PERCENTAGE_MAX_ENTROPY_SIZE,
    NUMBER_OF_VARS, NUMBER_OF_STATES, FILENAME_FORMAT_INPUT, 
    distribution_numbers
)
output_dists = get_data.get_system_distributions_limited_entropy(
    path_to_limited_entropy_system_dists, PERCENTAGE_MAX_ENTROPY_SIZE,
    NUMBER_OF_VARS, NUMBER_OF_STATES, FILENAME_FORMAT_OUTPUT, 
    distribution_numbers
)

impacts, missed_weight = get_random_nudge_impacts(
    input_dists, output_dists, NUDGE_SIZE, NUDGE_TYPE, 
    NUMBER_OF_SAMPLES, backup_filename, parameters
)

print(impacts)
filename_to_save_impacts =  "random_impacts_validate_{}var_{}states_{}entropy_{}_nudge_dists{}-{}.json".format(
    NUMBER_OF_VARS, NUMBER_OF_STATES, PERCENTAGE_MAX_ENTROPY_SIZE, NUDGE_TYPE, DIST_START, DIST_END 
)
with open("data_experiments/" + filename_to_save_impacts, 'w') as f:
    json.dump(impacts, f)
    
filename_to_save_missed_weight =  "missed_weight_validate{}var_{}states_{}entropy_{}_nudge_dists{}-{}.json".format(
    NUMBER_OF_VARS, NUMBER_OF_STATES, PERCENTAGE_MAX_ENTROPY_SIZE, NUDGE_TYPE, DIST_START, DIST_END 
)
with open("data_experiments/" + filename_to_save_missed_weight, 'w') as f:
    json.dump(missed_weight, f)
# Out:
# count 0
# the nudge impact 0.000350969971505
# WARNING missed weight equals 37.510106151 percentage of nudge_size
# count 1
# the nudge impact 0.00035906947215
# WARNING missed weight equals 35.481390854 percentage of nudge_size
# count 2
# the nudge impact 0.000384771024444
# WARNING missed weight equals 34.4930282155 percentage of nudge_size
# count 3
# the nudge impact 0.000378943698759
# WARNING missed weight equals 35.6551734357 percentage of nudge_size
# count 4
# the nudge impact 0.000419786141442
# WARNING missed weight equals 36.2970775719 percentage of nudge_size
# count 5
# the nudge impact 0.000378217524953
# WARNING missed weight equals 39.0076597365 percentage of nudge_size
# count 6
# the nudge impact 0.000407237103443
# WARNING missed weight equals 35.7832524139 percentage of nudge_size
# count 7
# the nudge impact 0.000378466591301
# WARNING missed weight equals 35.9421101226 percentage of nudge_size
# count 8
# the nudge impact 0.000404840884894
# WARNING missed weight equals 35.2900654342 percentage of nudge_size
# count 9
# the nudge impact 0.000357666523869
# WARNING missed weight equals 36.5533748214 percentage of nudge_size
# count 10
# the nudge impact 0.000394604977875
# WARNING missed weight equals 37.0114537901 percentage of nudge_size
# count 11
# the nudge impact 0.00038373261429
# WARNING missed weight equals 35.745339443 percentage of nudge_size
# count 12
# the nudge impact 0.000406288672079
# WARNING missed weight equals 36.4587638013 percentage of nudge_size
# count 13
# the nudge impact 0.000346069533493
# WARNING missed weight equals 37.2229197581 percentage of nudge_size
# count 14
# the nudge impact 0.000399087845623
# WARNING missed weight equals 34.9855231248 percentage of nudge_size
# count 15
# the nudge impact 0.000367836722231
# WARNING missed weight equals 37.6052586779 percentage of nudge_size
# count 16
# the nudge impact 0.000404800353143
# WARNING missed weight equals 34.1060533477 percentage of nudge_size
# count 17
# the nudge impact 0.000381109192129
# WARNING missed weight equals 33.8317655447 percentage of nudge_size
# count 18
# the nudge impact 0.00034860964163
# WARNING missed weight equals 38.6566368092 percentage of nudge_size
# count 19
# the nudge impact 0.000368044583831
# WARNING missed weight equals 34.6710034669 percentage of nudge_size
# count 20
# the nudge impact 0.000397456657686
# WARNING missed weight equals 35.0090365607 percentage of nudge_size
# count 21
# the nudge impact 0.000381929476096
# WARNING missed weight equals 37.6322898698 percentage of nudge_size
# count 22
# the nudge impact 0.000424672892174
# WARNING missed weight equals 35.3067675473 percentage of nudge_size
# count 23
# the nudge impact 0.000376621517947
# WARNING missed weight equals 36.8146673711 percentage of nudge_size
# count 24
# the nudge impact 0.000399960089226
# WARNING missed weight equals 37.4184753852 percentage of nudge_size
# count 25
# the nudge impact 0.00040080589137
# WARNING missed weight equals 37.0903498068 percentage of nudge_size
# count 26
# the nudge impact 0.000395709119221
# WARNING missed weight equals 35.9055057106 percentage of nudge_size
# count 27
# the nudge impact 0.000418582852616
# WARNING missed weight equals 38.2339600634 percentage of nudge_size
# count 28
# the nudge impact 0.000424865493846
# WARNING missed weight equals 36.0909702015 percentage of nudge_size
# count 29
# the nudge impact 0.000394258730038
# WARNING missed weight equals 34.8832827002 percentage of nudge_size
# count 30
# the nudge impact 0.000392965135029
# WARNING missed weight equals 36.8132806147 percentage of nudge_size
# count 31
# the nudge impact 0.000388267013807
# WARNING missed weight equals 34.1827109033 percentage of nudge_size
# count 32
# the nudge impact 0.000370629480139
# WARNING missed weight equals 36.4615686127 percentage of nudge_size
# count 33
# the nudge impact 0.000371660422588
# WARNING missed weight equals 35.9051432663 percentage of nudge_size
# count 34
# the nudge impact 0.000343552672309
# WARNING missed weight equals 36.6985259679 percentage of nudge_size
# count 35
# the nudge impact 0.000378368519216
# WARNING missed weight equals 36.9141942341 percentage of nudge_size
# count 36
# the nudge impact 0.000390367641491
# WARNING missed weight equals 35.3317530548 percentage of nudge_size
# count 37
# the nudge impact 0.000397148950991
# WARNING missed weight equals 36.7880356304 percentage of nudge_size
# count 38
# the nudge impact 0.000395731578374
# WARNING missed weight equals 33.8803911034 percentage of nudge_size
# count 39
# the nudge impact 0.000418411118062
# WARNING missed weight equals 34.3897774567 percentage of nudge_size
# count 40
# the nudge impact 0.000397452885311
# WARNING missed weight equals 35.9476342164 percentage of nudge_size
# count 41
# the nudge impact 0.000424267368467
# WARNING missed weight equals 37.4388431626 percentage of nudge_size
# count 42
# the nudge impact 0.000430507577111
# WARNING missed weight equals 37.1332798305 percentage of nudge_size
# count 43
# the nudge impact 0.000427174141237
# WARNING missed weight equals 33.9739275801 percentage of nudge_size
# count 44
# the nudge impact 0.000378152255438
# WARNING missed weight equals 37.3003875021 percentage of nudge_size
# count 45
# the nudge impact 0.000370395335786
# WARNING missed weight equals 36.1134418523 percentage of nudge_size
# count 46
# the nudge impact 0.000370430054291
# WARNING missed weight equals 36.5200116199 percentage of nudge_size
# count 47
# the nudge impact 0.000400900084305
# WARNING missed weight equals 36.4048574284 percentage of nudge_size
# count 48
# the nudge impact 0.000360523200872
# WARNING missed weight equals 36.4284011765 percentage of nudge_size
# count 49
# the nudge impact 0.000394768621339
# WARNING missed weight equals 36.8191892985 percentage of nudge_size
# count 50
# the nudge impact 0.000379914156451
# WARNING missed weight equals 33.7023285926 percentage of nudge_size
# count 51
# the nudge impact 0.000394275140295
# WARNING missed weight equals 36.0604269637 percentage of nudge_size
# count 52
# the nudge impact 0.000407548893039
# WARNING missed weight equals 34.5171519084 percentage of nudge_size
# count 53
# the nudge impact 0.000346167204292
# WARNING missed weight equals 36.6324226471 percentage of nudge_size
# count 54
# the nudge impact 0.000369594548921
# WARNING missed weight equals 37.6219952175 percentage of nudge_size
# count 55
# the nudge impact 0.000386565915944
# WARNING missed weight equals 37.6791035192 percentage of nudge_size
# count 56
# the nudge impact 0.000383002841475
# WARNING missed weight equals 35.9627427383 percentage of nudge_size
# count 57
# the nudge impact 0.000361723408491
# WARNING missed weight equals 37.323831531 percentage of nudge_size
# count 58
# the nudge impact 0.000366739151547
# WARNING missed weight equals 35.1724961565 percentage of nudge_size
# count 59
# the nudge impact 0.000394989780004
# WARNING missed weight equals 37.2085950352 percentage of nudge_size
# count 60
# the nudge impact 0.000410459375086
# WARNING missed weight equals 34.5622145921 percentage of nudge_size
# count 61
# the nudge impact 0.000366554489111
# WARNING missed weight equals 34.8120633004 percentage of nudge_size
# count 62
# the nudge impact 0.000361699877909
# WARNING missed weight equals 36.3923809298 percentage of nudge_size
# count 63
# the nudge impact 0.000377329268811
# WARNING missed weight equals 35.2657438927 percentage of nudge_size
# count 64
# the nudge impact 0.000403302983039
# WARNING missed weight equals 36.0951441588 percentage of nudge_size
# count 65
# the nudge impact 0.000396358615422
# WARNING missed weight equals 36.7784508993 percentage of nudge_size
# count 66
# the nudge impact 0.000380177713213
# WARNING missed weight equals 35.9302925908 percentage of nudge_size
# count 67
# the nudge impact 0.000406581321971
# WARNING missed weight equals 36.5448907938 percentage of nudge_size
# count 68
# the nudge impact 0.0003754766736
# WARNING missed weight equals 35.9833419566 percentage of nudge_size
# count 69
# the nudge impact 0.000371471504421
# WARNING missed weight equals 37.1493779817 percentage of nudge_size
# count 70
# the nudge impact 0.000382174738061
# WARNING missed weight equals 35.9725566118 percentage of nudge_size
# count 71
# the nudge impact 0.00037794237314
# WARNING missed weight equals 37.1593127045 percentage of nudge_size
# count 72
# the nudge impact 0.00037210112229
# WARNING missed weight equals 34.677302385 percentage of nudge_size
# count 73
# the nudge impact 0.000377086478375
# WARNING missed weight equals 38.4407171363 percentage of nudge_size
# count 74
# the nudge impact 0.000365079710427
# WARNING missed weight equals 37.950710344 percentage of nudge_size
# count 75
# the nudge impact 0.000392916240755
# WARNING missed weight equals 35.9045131572 percentage of nudge_size
# count 76
# the nudge impact 0.000377410625283
# WARNING missed weight equals 36.3392983664 percentage of nudge_size
# count 77
# the nudge impact 0.000416817919808
# WARNING missed weight equals 34.0904368551 percentage of nudge_size
# count 78
# the nudge impact 0.000342769907453
# WARNING missed weight equals 37.7244445149 percentage of nudge_size
# count 79
# the nudge impact 0.000375046836677
# WARNING missed weight equals 35.6913509099 percentage of nudge_size
# count 80
# the nudge impact 0.000344841180509
# WARNING missed weight equals 33.532958195 percentage of nudge_size
# count 81
# the nudge impact 0.000370581983881
# WARNING missed weight equals 33.6262388816 percentage of nudge_size
# count 82
# the nudge impact 0.000356429213421
# WARNING missed weight equals 35.3337402648 percentage of nudge_size
# count 83
# the nudge impact 0.000414164373086
# WARNING missed weight equals 36.9607802296 percentage of nudge_size
# count 84
# the nudge impact 0.000382149006947
# WARNING missed weight equals 34.5455287896 percentage of nudge_size
# count 85
# the nudge impact 0.000399169507971
# WARNING missed weight equals 35.649667624 percentage of nudge_size
# count 86
# the nudge impact 0.000389653865301
# WARNING missed weight equals 36.9604586087 percentage of nudge_size
# count 87
# the nudge impact 0.000428767160951
# WARNING missed weight equals 35.2222485409 percentage of nudge_size
# count 88
# the nudge impact 0.000391119922367
# WARNING missed weight equals 36.0025273354 percentage of nudge_size
# count 89
# the nudge impact 0.000376490110954
# WARNING missed weight equals 37.8639646102 percentage of nudge_size
# count 90
# the nudge impact 0.000393967025973
# WARNING missed weight equals 34.3344194694 percentage of nudge_size
# count 91
# the nudge impact 0.000400717552252
# WARNING missed weight equals 35.563787301 percentage of nudge_size
# count 92
# the nudge impact 0.000383646304713
# WARNING missed weight equals 36.1365729656 percentage of nudge_size
# count 93
# the nudge impact 0.000401513355162
# WARNING missed weight equals 35.5140164528 percentage of nudge_size
# count 94
# the nudge impact 0.000385917496624
# WARNING missed weight equals 35.7771107177 percentage of nudge_size
# count 95
# the nudge impact 0.000352696873104
# WARNING missed weight equals 36.9874349956 percentage of nudge_size
# count 96
# the nudge impact 0.000413424065079
# WARNING missed weight equals 35.605609376 percentage of nudge_size
# count 97
# the nudge impact 0.000389249932889
# WARNING missed weight equals 38.6618790994 percentage of nudge_size
# count 98
# the nudge impact 0.000398576128298
# WARNING missed weight equals 37.5469520657 percentage of nudge_size
# count 99
# the nudge impact 0.00039609983054
# WARNING missed weight equals 36.3650452118 percentage of nudge_size
# total missed weight 0.361167519537
# [0.00035096997150541655, 0.00035906947214990159, 0.00038477102444360258, 0.00037894369875870359, 0.00041978614144170368, 0.00037821752495251546, 0.00040723710344269806, 0.00037846659130077011, 0.00040484088489360192, 0.00035766652386949924, 0.00039460497787530244, 0.00038373261428976236, 0.00040628867207943674, 0.00034606953349326455, 0.00039908784562293296, 0.0003678367222312412, 0.00040480035314339081, 0.00038110919212852145, 0.00034860964162957976, 0.00036804458383116081, 0.00039745665768631754, 0.00038192947609550165, 0.00042467289217402337, 0.00037662151794726819, 0.00039996008922581704, 0.00040080589136971655, 0.00039570911922076954, 0.00041858285261556829, 0.0004248654938458374, 0.00039425873003827829, 0.00039296513502900198, 0.00038826701380717754, 0.00037062948013853237, 0.00037166042258750644, 0.00034355267230886055, 0.00037836851921638161, 0.00039036764149121103, 0.00039714895099125016, 0.00039573157837390738, 0.00041841111806199924, 0.00039745288531069787, 0.00042426736846723099, 0.0004305075771109723, 0.0004271741412368524, 0.00037815225543759212, 0.00037039533578597962, 0.00037043005429123312, 0.00040090008430546001, 0.00036052320087238856, 0.00039476862133903891, 0.00037991415645120764, 0.00039427514029490241, 0.00040754889303946609, 0.00034616720429159198, 0.0003695945489205099, 0.0003865659159438195, 0.00038300284147509687, 0.00036172340849089881, 0.00036673915154654846, 0.00039498978000410969, 0.00041045937508593476, 0.00036655448911076307, 0.00036169987790922231, 0.00037732926881134556, 0.00040330298303929479, 0.0003963586154215376, 0.00038017771321253335, 0.0004065813219710801, 0.00037547667360039619, 0.0003714715044207517, 0.00038217473806076484, 0.00037794237313960589, 0.00037210112229038583, 0.00037708647837504048, 0.00036507971042721074, 0.00039291624075517506, 0.00037741062528308611, 0.00041681791980765381, 0.00034276990745272016, 0.00037504683667702543, 0.00034484118050882693, 0.00037058198388065678, 0.00035642921342144362, 0.00041416437308641751, 0.00038214900694748868, 0.000399169507970783, 0.00038965386530078085, 0.00042876716095058108, 0.00039111992236665115, 0.00037649011095426731, 0.0003939670259729805, 0.00040071755225243143, 0.00038364630471295291, 0.00040151335516170781, 0.00038591749662375053, 0.00035269687310362065, 0.00041342406507858756, 0.00038924993288871277, 0.00039857612829847676, 0.00039609983053989274]

# %%
from scipy import stats

PERCENTAGE_MAX_ENTROPY_SIZE = 75
input_dists = get_data.get_system_distributions_limited_entropy(
    path_to_limited_entropy_system_dists, PERCENTAGE_MAX_ENTROPY_SIZE,
    NUMBER_OF_VARS, NUMBER_OF_STATES, FILENAME_FORMAT_INPUT, 
    distribution_numbers
)

output_dists = get_data.get_system_distributions_limited_entropy(
    path_to_limited_entropy_system_dists, PERCENTAGE_MAX_ENTROPY_SIZE,
    NUMBER_OF_VARS, NUMBER_OF_STATES, FILENAME_FORMAT_OUTPUT, 
    distribution_numbers
)

for input_dist, cond_output in zip(input_dists, output_dists):
    joint = probability_distributions.compute_joint(input_dist, cond_output, set(list(range(NUMBER_OF_VARS-1)))) 
    print("goal entropy {}".format(0.75*np.log2(joint.flatten().shape[0])))
    print(stats.entropy(joint.flatten(), base=2))
